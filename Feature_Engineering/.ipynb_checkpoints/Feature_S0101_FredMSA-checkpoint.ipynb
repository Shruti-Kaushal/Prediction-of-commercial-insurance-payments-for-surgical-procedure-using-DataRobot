# %%
import os
os.getcwd()
# Out:
# '/Users/shrutikaushal/Documents/GitHub/Prediction-of-commercial-insurance-payments-for-surgical-procedure-using-DataRobot/Feature_Engineering'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats.stats import pearsonr
from Prediction-of-commercial-insurance-payments-for-surgical-procedure-using-DataRobot.Common_Functions.processing_functions import add_unique_identifier, data_split
# Out:
#   File "<ipython-input-4-71086646aa50>", line 7
#     from Prediction-of-commercial-insurance-payments-for-surgical-procedure-using-DataRobot.Common_Functions.processing_functions import add_unique_identifier, data_split
#                    ^
# SyntaxError: invalid syntax

# %%
data = pd.read_csv('priv_mcare_f_pay_2022Oct18.csv')
data = add_unique_identifier(data)
model_data, future_data = data_split(data, count_col_name = 'priv_count')
data = model_data

# %%
data.head()
# Out:
#                                                   id      msa  year  \
# 62502   26420.0_2018_Inpatient_breast reconstruction  26420.0  2018
# 62503  28660.0_2018_Outpatient_breast reconstruction  28660.0  2018
# 62504  37340.0_2018_Outpatient_breast reconstruction  37340.0  2018
# 62505  26620.0_2019_Outpatient_breast reconstruction  26620.0  2019
# 62506  15980.0_2020_Outpatient_breast reconstruction  15980.0  2020
#
#              site                  group  priv_count  priv_pay_mean  \
# 62502   Inpatient  breast reconstruction        51.0   47327.576470
# 62503  Outpatient  breast reconstruction        51.0    8048.568431
# 62504  Outpatient  breast reconstruction        51.0   34211.443140
# 62505  Outpatient  breast reconstruction        51.0    6233.098627
# 62506  Outpatient  breast reconstruction        51.0   21964.297060
#
#        priv_pay_median  priv_pay_iqr  mcare_count  mcare_los  mcare_pay_mean  \
# ...

# %% [markdown]
# # S0101 - Age and Sex data

# %% [markdown]
# ### Merging datasets

# %%
age_sex = pd.read_csv('Age_Sex_Data/ACSST1Y2021.S0101-Data.csv')
age_sex.columns = ['GEO_ID','Name','total_population','median_age','sex_ratio']

# %%
# there are 18 MSAs in the data for which we do not have population attributes
no_match_areas = set(data.CBSA_NAME.dropna()) - set(age_sex.Name)
print(len(no_match_areas))
# Out:
# 13

# %%
potential_match = {}
for area in no_match_areas:
    potential_match[area] = []
    state = area.split(', ')[-1]
    county_names = area.split(', ')[0].split(' ')
    for x in set(age_sex.Name):
        if state in x:
            if len(set(county_names).intersection(set(x.split(', ')[0].split( ))))!=0:
                potential_match[area].append(x)

# %%
data_age_sex = pd.merge(data, age_sex, left_on = 'CBSA_NAME', right_on = 'Name')
data_age_sex.dropna(subset = ['priv_count','priv_pay_mean'], inplace = True)

# %%
data_age_sex.head(2)
# Out:
#                                              id      msa  year       site  \
# 0  26420.0_2018_Inpatient_breast reconstruction  26420.0  2018  Inpatient
# 1                  26420.0_2020_Inpatient_hepat  26420.0  2020  Inpatient
#
#                    group  priv_count  priv_pay_mean  priv_pay_median  \
# 0  breast reconstruction        51.0    47327.57647          21408.0
# 1                  hepat        51.0   146073.78960          29225.0
#
#    priv_pay_iqr  mcare_count  ...  mcare_pay_sd  \
# 0     23351.715         81.0  ...   12242.65415
# 1    127959.495        451.0  ...   67542.61599
#
#                               CBSA_NAME  State        lon        lat  \
# 0  Houston-The Woodlands-Sugar Land, TX  Texas -95.622552  29.598443
# 1  Houston-The Woodlands-Sugar Land, TX  Texas -95.622552  29.598443
#
#            GEO_ID                                  Name  total_population  \
# 0  310M600US26420  Houston-The Woodlands-Sugar Land, TX           7206841
# ...

# %% [markdown]
# ## Correlation Analysis

# %%
data_age_sex.corr()
# Out:
#                        msa      year  priv_count  priv_pay_mean  \
# msa               1.000000  0.001356   -0.019689      -0.012378
# year              0.001356  1.000000   -0.074167       0.034527
# priv_count       -0.019689 -0.074167    1.000000      -0.123504
# priv_pay_mean    -0.012378  0.034527   -0.123504       1.000000
# priv_pay_median  -0.012145  0.034740   -0.125316       0.961165
# priv_pay_iqr     -0.008406  0.028305   -0.082813       0.861011
# mcare_count       0.021859 -0.018919    0.305423       0.292167
# mcare_los         0.005769 -0.027745   -0.110141       0.596193
# mcare_pay_mean   -0.008223  0.041580   -0.128689       0.882323
# mcare_pay_median -0.000244  0.043910   -0.128432       0.866203
# mcare_pay_sd     -0.015759  0.034581   -0.084094       0.696924
# lon              -0.069613  0.005720    0.023327       0.015633
# lat               0.075994 -0.012554   -0.045280      -0.080922
# total_population  0.070520  0.029794    0.250530       0.233340
# ...

# %%
temp = data_age_sex.dropna()
pearsonr(temp.mcare_pay_mean, temp.total_population)
# Out:
# (0.23707889651742747, 7.208184412181685e-38)

# %% [markdown]
# ### Calculating correlations per group

# %%
pvalue_group_df = pd.DataFrame(columns = ['group','total_population','median_age','sex_ratio'])
pvalue_group_df['group'] = np.unique(data_age_sex.group)

corr_group_df = pd.DataFrame(columns = ['group','total_population','median_age','sex_ratio'])
corr_group_df['group'] = np.unique(data_age_sex.group)

# %%
alpha = 0.05
groups_removed = []
for col in pvalue_group_df.columns[1:]:
    pvalues = []
    corr = []
    for group in np.unique(pvalue_group_df.group):
        temp = data_age_sex[data_age_sex.group == group]
        if temp.shape[0]<=2:
            pvalues.append(np.nan)
            corr.append(np.nan)
            if group not in groups_removed:
                groups_removed.append(group)
        else:
            coeff,pv = pearsonr(temp.priv_pay_mean,temp[col])
            pvalues.append(pv)
            corr.append(coeff)
    pvalue_group_df[col] = pvalues
    corr_group_df[col] = corr

pvalue_group_df.index = pvalue_group_df.group
pvalue_group_df.drop(columns = ['group'], inplace = True)

corr_group_df.index = corr_group_df.group
corr_group_df.drop(columns = ['group'], inplace = True)

# %% [markdown]
# 8 procedure groups had less than 2 observations in the model data and so were not included in correlation analysis

# %%
groups_removed
# Out:
# ['cardiac ablation_linear_focal',
#  'clavicle fixation',
#  'pka',
#  'post_cerv_fusion',
#  'prox_tibia_fixation',
#  'thoracic',
#  'tpa',
#  'tsa']

# %%
labels = corr_group_df.dropna().copy()
for group in labels.index:
    for col in labels.columns:
        if pvalue_group_df[col][group] >= 0.05:
            labels[col][group] = np.nan

labels = labels.round(2)
annotations = labels.astype(str)
annotations[np.isnan(labels)] = ""

# %%
plt.figure(figsize = (5,10))
sns.heatmap(corr_group_df.dropna(),vmin=-1, vmax=1, center = 0, cmap = 'vlag', linecolor = 'black', \
            linewidth = 0.2, annot = annotations, fmt = 's')
plt.title('Correlation Plot for Mean Commercial Payments')
plt.savefig('corr_group_age_sex.png', bbox_inches = 'tight')
plt.show()

# %%
fig, axes = plt.subplots(2,1, sharex = True, figsize = (6.5,4.5))

fig0_data = data.groupby(by = ['msa']).std().reset_index().dropna()['priv_pay_median']
sns.histplot(fig0_data, stat = 'probability', ax = axes[0])
axes[0].set_ylim(0,1)
axes[0].set_title('Median Private Payments per MSA')

fig1_data = data.groupby(by = ['group']).std().reset_index().dropna()['priv_pay_median']
sns.histplot(fig1_data, stat = 'probability', ax = axes[1])
axes[1].set_ylim(0,1)
axes[1].set_title('Median Private Payments per Procedure Group')

plt.xlabel('Standard Deviation', fontsize = 12)
plt.ylabel('Probability', fontsize = 12)
plt.suptitle('Histogram of Standard Deviations in Median Private Payments')

# plt.savefig('hist_priv_pay_median_MSAgroup.png', bbox_inches = 'tight')
plt.show()

# %%
index_sort = data.groupby(by = 'group').mean().sort_values('priv_pay_mean', ascending = False).index

plt.figure(figsize = (10,10))
sns.boxplot(y = 'group', x = 'priv_pay_mean', data = data.dropna(), order = index_sort, showmeans = True,\
           meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"5"})
plt.grid()
plt.xlabel('Mean Private Payments', fontsize = 12)
plt.ylabel('Procedure Group', fontsize = 12)
plt.title('Distribution of Mean Private Payments per Procedure Group', fontsize = 14)
plt.savefig('boxplot_priv_pay_mean_group.png', bbox_inches = 'tight')
plt.show()

# %%
plt.figure(figsize = (10,25))
sns.boxplot(y = 'group', x = 'priv_pay_mean', hue = 'site', data = data.dropna(), order = index_sort, showmeans = True,\
           meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"5"})
plt.grid()
plt.xlabel('Mean Private Payments', fontsize = 12)
plt.ylabel('Procedure Group', fontsize = 12)
plt.title('Distribution of Mean Private Payments per Procedure Group and Site', fontsize = 14)
plt.legend(bbox_to_anchor = (1,1))
plt.savefig('boxplot_priv_pay_mean_groupSite.png', bbox_inches = 'tight')
plt.show()

# %%
rp = sns.FacetGrid(data, row = "group",aspect=9, height=1.2)
rp.map(sns.kdeplot,"priv_pay_mean", fill = True)
plt.savefig('ridgeplot_priv_pay_mean_perGroup.png', bbox_inches = 'tight')
plt.show()
# Out:
# /Users/shrutikaushal/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
rp = sns.FacetGrid(data, row = "group", col = "site", aspect = 1.5)
rp.map(sns.kdeplot,"priv_pay_mean", fill = True)
plt.savefig('ridgeplot_priv_pay_mean_perGroupSite.png', bbox_inches = 'tight')
plt.show()
# Out:
# /Users/shrutikaushal/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/shrutikaushal/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
