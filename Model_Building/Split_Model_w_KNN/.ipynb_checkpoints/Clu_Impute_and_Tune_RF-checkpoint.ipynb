# %% [markdown]
# # Tree-based Models, with Clusters

# %% [markdown]
# ## Library Imports

# %%
# Necessary code to import our helper functions
import sys
sys.path.append("../..")

# %%
# Library imports
import numpy as np
import pandas as pd
from category_encoders import TargetEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.impute import KNNImputer
from matplotlib import pyplot as plt
import xgboost as xgb
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler
from Common_Functions import data_split, add_unique_identifier, data_cleaning, hospital_data_agg, optimal_k
# Out:
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
# Method from Shruti's code
def standardize_data(train_data, val_data):
    train_temp = train_data.drop(columns = ['site','cluster','lat','lon'])
    val_temp = val_data.drop(columns = ['site','cluster','lat','lon'])
    
    scaler = MinMaxScaler()
    
    train_data_scaled = scaler.fit_transform(train_temp)
    train_data_scaled = pd.DataFrame(train_data_scaled, columns = train_temp.columns)
    train_data_scaled['cluster'] = train_data['cluster'].to_list()
    train_data_scaled['site'] = train_data['site'].to_list()
    train_data_scaled['lat'] = train_data['lat'].to_list()
    train_data_scaled['lon'] = train_data['lon'].to_list()
    
    val_data_scaled = scaler.transform(val_temp)
    val_data_scaled = pd.DataFrame(val_data_scaled, columns = val_temp.columns)
    val_data_scaled['cluster'] = val_data['cluster'].to_list()
    val_data_scaled['site'] = val_data['site'].to_list()
    val_data_scaled['lat'] = val_data['lat'].to_list()
    val_data_scaled['lon'] = val_data['lon'].to_list()
    
    return train_data_scaled, val_data_scaled

# %%
# Method slightly modified from Shruti's code
def impute_knn(train_data, val_data, optimal_k): 
    train_data_scaled, val_data_scaled = standardize_data(train_data, val_data)

    knn = KNNImputer(n_neighbors = optimal_k)

    # imputing values
    train_data_scaled[list(train_data_scaled.columns)] = knn.fit_transform(train_data_scaled)
    val_data_scaled[list(val_data_scaled.columns)] = knn.transform(val_data_scaled)
    
    return train_data_scaled, val_data_scaled

# %% [markdown]
# ## Data Import

# %%
data = pd.read_csv("../../Feature Matrix/processed_data.csv")
data.dropna(subset = ['mcare_count'], inplace = True)
data.drop(columns = ['year'], inplace = True)
data.replace([np.inf, -np.inf], 0, inplace=True)

# %% [markdown]
# ## Model Parameters

# %%
COUNT_THRESH = 34
RDM_SEED = 123
TRAIN_TEST_PROPORTION = 0.8

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# ### One-Hot Categorical Encoding and Dropping NAs

# %%
data = data_cleaning(data, dropna = False, one_hot = False)

# %% [markdown]
# ### Data Split

# %%
working_set, predict_set = data_split(data, count_thresh = COUNT_THRESH)

# %%
model_data = working_set
predict_data = predict_set

# %%
display(model_data)
# Out:
#        site                  group  priv_count  priv_pay_median  mcare_los  \
# 40        1  breast reconstruction          63        24289.900   2.549296
# 70        1  breast reconstruction          51        21408.000   3.543210
# 112       1  breast reconstruction          64        29757.100   3.918699
# 219       1  breast reconstruction          66        25240.905   3.241935
# 275       1  breast reconstruction          45        34963.900   3.262295
# ...     ...                    ...         ...              ...        ...
# 44974     0        ant_cerv_fusion          54        17137.490        NaN
# 44991     0        ant_cerv_fusion          39        11807.250        NaN
# 45038     0        ant_cerv_fusion          35        18421.250        NaN
# 45100     0        ant_cerv_fusion          51        13926.250        NaN
# 45218     0        ant_cerv_fusion          44        17554.080        NaN
#
#        mcare_pay_median                              CBSA_NAME        lon  \
# 40             8794.190        Dallas-Fort Worth-Arlington, TX -96.920913
# 70            10395.160   Houston-The Woodlands-Sugar Land, TX -95.622552
# 112           14174.100  New York-Newark-Jersey City, NY-NJ-PA -74.005954
# 219           10144.445        Dallas-Fort Worth-Arlington, TX -96.920913
# 275           14008.190  New York-Newark-Jersey City, NY-NJ-PA -74.005954
# ...                 ...                                    ...        ...
# 44974          6934.483   Atlanta-Sandy Springs-Alpharetta, GA -84.294090
# 44991          6905.252      Charlotte-Concord-Gastonia, NC-SC -80.721440
# 45038          6724.500                      Memphis, TN-MS-AR -89.850500
# 45100          7334.787   Atlanta-Sandy Springs-Alpharetta, GA -84.294090
# 45218          8108.762   Atlanta-Sandy Springs-Alpharetta, GA -84.294090
#
#              lat  Hospitals  ...  annual_births  frac_veteran  \
# 40     32.707875      114.0  ...      1974825.0          0.06
# 70     29.598443      181.0  ...      1808878.0          0.05
# 112    40.712776      143.0  ...      4668590.0          0.03
# 219    32.707875      114.0  ...      1974825.0          0.06
# 275    40.712776      143.0  ...      4668590.0          0.03
# ...          ...        ...  ...            ...           ...
# 44974  34.075380       80.0  ...      1573561.0          0.07
# 44991  35.122320       26.0  ...       673803.0          0.06
# 45038  35.038720       28.0  ...       327202.0          0.07
# 45100  34.075380       80.0  ...      1573561.0          0.07
# 45218  34.075380       80.0  ...      1573561.0          0.07
#
#        frac_disability  non_citizen  employment_rate  frac_priv_insurance  \
# 40                0.10         0.59             0.69                 0.66
# 70                0.10         0.57             0.66                 0.60
# 112               0.11         0.41             0.65                 0.66
# 219               0.10         0.59             0.69                 0.66
# 275               0.11         0.41             0.65                 0.66
# ...                ...          ...              ...                  ...
# 44974             0.11         0.48             0.67                 0.70
# 44991             0.11         0.57             0.67                 0.69
# 45038             0.13         0.64             0.64                 0.64
# 45100             0.11         0.48             0.67                 0.70
# 45218             0.11         0.48             0.67                 0.70
#
#        frac_mcare_insurance  frac_no_insurance  cluster  mcare_count
# 40                     0.25               0.17        0         71.0
# 70                     0.28               0.19        0         81.0
# 112                    0.39               0.07        0        123.0
# 219                    0.25               0.17        0         62.0
# 275                    0.39               0.07        0        122.0
# ...                     ...                ...      ...          ...
# 44974                  0.28               0.12        2          0.0
# 44991                  0.31               0.10        2          0.0
# 45038                  0.37               0.11        2          0.0
# 45100                  0.28               0.12        2          0.0
# 45218                  0.28               0.12        2          0.0
#
# [4677 rows x 35 columns]

# %% [markdown]
# ## Dev/Test Split

# %%
X_input = model_data.drop(columns=["priv_pay_median"])
y_input = model_data["priv_pay_median"]

# display(X_input)
# display(y_input)

X_dev, X_test, y_dev, y_test = train_test_split(X_input,
                                                y_input,
                                                train_size = TRAIN_TEST_PROPORTION,
                                                random_state = RDM_SEED)
display(X_dev)
# Out:
#        site                          group  priv_count  mcare_los  \
# 22077     0                           fess          69   0.000000
# 7644      0                  rtc_slap_bank          50   0.000000
# 16125     1                            tka         230   1.800551
# 31370     0                         hernia          44   0.000000
# 13308     1                            tha          62   2.970817
# ...     ...                            ...         ...        ...
# 13859     1                            tha          47   3.479332
# 33698     0                      hysterect         223   0.000000
# 12634     0  radius/ulna internal fixation          37   0.000000
# 30258     1                         hernia          48   5.243728
# 31512     0                         hernia         202   0.000000
#
#        mcare_pay_median                                   CBSA_NAME  \
# 22077           3698.19                                Muskegon, MI
# 7644            4341.63                                 Jackson, MI
# 16125          10385.95        Houston-The Woodlands-Sugar Land, TX
# 31370           2132.26                           Memphis, TN-MS-AR
# 13308          10201.24                       Birmingham-Hoover, AL
# ...                 ...                                         ...
# 13859          15409.19                Seattle-Bellevue-Everett, WA
# 33698           7867.29         Portland-Vancouver-Hillsboro, OR-WA
# 12634           4160.69  Virginia Beach-Norfolk-Newport News, VA-NC
# 30258          10176.57        Atlanta-Sandy Springs-Alpharetta, GA
# 31512           2375.98        Atlanta-Sandy Springs-Alpharetta, GA
#
#               lon        lat  Hospitals  PctTeaching  ...  annual_births  \
# 22077  -86.248392  43.234181        5.0     0.400000  ...            NaN
# 7644   -84.401346  42.245869        2.0     0.000000  ...            NaN
# 16125  -95.622552  29.598443      181.0     0.088398  ...      1808878.0
# 31370  -89.850500  35.038720       28.0     0.357143  ...       327202.0
# 13308  -86.811378  33.405387       24.0     0.250000  ...       264679.0
# ...           ...        ...        ...          ...  ...            ...
# 13859 -122.195948  47.607680       38.0     0.368421  ...            NaN
# 33698 -122.546300  45.653680       30.0     0.366667  ...       617728.0
# 12634  -76.285873  36.850769       20.0     0.500000  ...       434583.0
# 30258  -84.294090  34.075380       80.0     0.162500  ...      1573561.0
# 31512  -84.294090  34.075380       80.0     0.162500  ...      1573561.0
#
#        frac_veteran  frac_disability  non_citizen  employment_rate  \
# 22077           NaN              NaN          NaN              NaN
# 7644            NaN              NaN          NaN              NaN
# 16125          0.05             0.10         0.57             0.66
# 31370          0.07             0.13         0.64             0.64
# 13308          0.06             0.15         0.58             0.61
# ...             ...              ...          ...              ...
# 13859           NaN              NaN          NaN              NaN
# 33698          0.07             0.13         0.43             0.66
# 12634          0.15             0.14         0.38             0.67
# 30258          0.07             0.11         0.48             0.67
# 31512          0.07             0.11         0.48             0.67
#
#        frac_priv_insurance  frac_mcare_insurance  frac_no_insurance  cluster  \
# 22077                  NaN                   NaN                NaN        0
# 7644                   NaN                   NaN                NaN        0
# 16125                 0.60                  0.28               0.19        2
# 31370                 0.64                  0.37               0.11        2
# 13308                 0.69                  0.35               0.08        2
# ...                    ...                   ...                ...      ...
# 13859                  NaN                   NaN                NaN        2
# 33698                 0.72                  0.35               0.06        0
# 12634                 0.74                  0.36               0.06        0
# 30258                 0.70                  0.28               0.12        2
# 31512                 0.70                  0.28               0.12        2
#
#        mcare_count
# 22077         81.0
# 7644          99.0
# 16125       1815.0
# 31370        189.0
# 13308       1028.0
# ...            ...
# 13859       1137.0
# 33698        203.0
# 12634        141.0
# 30258        279.0
# 31512        392.0
#
# [3741 rows x 34 columns]

# %% [markdown]
# ## Split Model Data by Cluster

# %%
# y_dev = y_dev.reset_index()['priv_pay_median']
# y_test = y_test.reset_index()['priv_pay_median']

X_dev_list = []
y_dev_list = []
X_test_list = []
y_test_list = []
optimal_k_list = []

for cluster_label in model_data["cluster"].unique():
    X_dev_clu = X_dev[X_dev["cluster"] == cluster_label]
    y_dev_clu = y_dev[X_dev["cluster"] == cluster_label]
    X_test_clu = X_test[X_test["cluster"] == cluster_label]
    y_test_clu = y_test[X_test["cluster"] == cluster_label]
    
    # Target encoding group variable
    te_group = TargetEncoder()
    X_dev_clu['group_encoded'] = te_group.fit_transform(X_dev_clu['group'],y_dev_clu)
    X_dev_clu.drop(columns = 'group', inplace = True)
    X_test_clu['group_encoded'] = te_group.transform(X_test_clu['group'])
    X_test_clu.drop(columns = 'group', inplace = True)

    # Target encoding CBSA Name
    te_CBSA_NAME = TargetEncoder()
    X_dev_clu['CBSA_NAME_encoded'] = te_CBSA_NAME.fit_transform(X_dev_clu['CBSA_NAME'],y_dev_clu)
    X_dev_clu.drop(columns = 'CBSA_NAME', inplace = True)
    X_test_clu['CBSA_NAME_encoded'] = te_CBSA_NAME.transform(X_test_clu['CBSA_NAME'])
    X_test_clu.drop(columns = 'CBSA_NAME', inplace = True)
    
    # KNN Imputation
    knn_data = X_dev_clu.copy()
    knn_data['priv_pay_median'] = y_dev_clu

    optimal_k_list.append(optimal_k(knn_data))
    print(optimal_k_list)

    X_dev_clu, X_test_clu = impute_knn(X_dev_clu, X_test_clu, optimal_k_list[-1])
    display(X_dev_clu)
    
    X_dev_list.append(X_dev_clu)
    y_dev_list.append(y_dev_clu)
    X_test_list.append(X_test_clu)
    y_test_list.append(y_test_clu)
    
    print(X_dev_clu.shape[0] / X_test_clu.shape[0])

display(X_dev_list[0])
# Out:
# C:\Users\rogmo\anaconda3\lib\site-packages\category_encoders\target_encoder.py:92: FutureWarning: Default parameter min_samples_leaf will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter min_samples_leaf will change in version 2.6."
# C:\Users\rogmo\anaconda3\lib\site-packages\category_encoders\target_encoder.py:97: FutureWarning: Default parameter smoothing will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter smoothing will change in version 2.6."
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_dev_clu['group_encoded'] = te_group.fit_transform(X_dev_clu['group'],y_dev_clu)
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_dev_clu.drop(columns = 'group', inplace = True)
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_clu['group_encoded'] = te_group.transform(X_test_clu['group'])
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_clu.drop(columns = 'group', inplace = True)
# C:\Users\rogmo\anaconda3\lib\site-packages\category_encoders\target_encoder.py:92: FutureWarning: Default parameter min_samples_leaf will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter min_samples_leaf will change in version 2.6."
# C:\Users\rogmo\anaconda3\lib\site-packages\category_encoders\target_encoder.py:97: FutureWarning: Default parameter smoothing will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter smoothing will change in version 2.6."
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_dev_clu['CBSA_NAME_encoded'] = te_CBSA_NAME.fit_transform(X_dev_clu['CBSA_NAME'],y_dev_clu)
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_dev_clu.drop(columns = 'CBSA_NAME', inplace = True)
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_clu['CBSA_NAME_encoded'] = te_CBSA_NAME.transform(X_test_clu['CBSA_NAME'])
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_clu.drop(columns = 'CBSA_NAME', inplace = True)
# [5]
#       priv_count  mcare_los  mcare_pay_median  Hospitals  PctTeaching  \
# 0       0.018231        0.0          0.184984   0.019704     0.400000
# 1       0.008043        0.0          0.217169   0.004926     0.000000
# 2       0.030563        0.0          0.205680   0.064039     0.428571
# 3       0.145308        0.0          0.193842   0.359606     0.229730
# 4       0.007507        0.0          0.170952   0.009852     0.666667
# ...          ...        ...               ...        ...          ...
# 2251    0.147989        0.0          0.229240   0.467980     0.427083
# 2252    0.044504        0.0          0.235769   0.034483     0.375000
# 2253    0.004290        0.0          0.166205   0.073892     0.500000
# 2254    0.100804        0.0          0.393522   0.142857     0.366667
# 2255    0.001072        0.0          0.208118   0.093596     0.500000
#
#       PctLargeHospital  PctPrivate  total_population  median_age  sex_ratio  \
# 0             0.000000    0.400000          0.004727    0.518657   0.422460
# 1             0.000000    0.000000          0.003891    0.559701   0.828877
# 2             0.214286    0.357143          0.051215    0.395522   0.540107
# 3             0.202703    0.702703          0.247025    0.436567   0.524064
# 4             0.000000    1.000000          0.007917    0.671642   0.208556
# ...                ...         ...               ...         ...        ...
# 2251          0.468750    0.427083          0.478889    0.470149   0.401070
# 2252          0.375000    0.875000          0.312174    0.500000   0.272727
# 2253          0.187500    0.625000          0.023094    0.675373   0.385027
# 2254          0.400000    0.666667          0.123304    0.492537   0.529412
# 2255          0.300000    0.500000          0.087527    0.417910   0.422460
#
#       ...  frac_priv_insurance  frac_mcare_insurance  frac_no_insurance  \
# 0     ...             0.795652              0.606061           0.085714
# 1     ...             0.795652              0.660606           0.085714
# 2     ...             0.847826              0.484848           0.071429
# 3     ...             0.652174              0.545455           0.285714
# 4     ...             0.678261              0.715152           0.257143
# ...   ...                  ...                   ...                ...
# 2251  ...             0.739130              0.484848           0.178571
# 2252  ...             0.804348              0.575758           0.071429
# 2253  ...             0.521739              0.969697           0.107143
# 2254  ...             0.782609              0.545455           0.107143
# 2255  ...             0.826087              0.575758           0.107143
#
#       mcare_count  group_encoded  CBSA_NAME_encoded  cluster  site        lat  \
# 0        0.018789       0.333397           0.171516      0.0   0.0  43.234181
# 1        0.022965       0.396554           0.140901      0.0   0.0  42.245869
# 2        0.026212       0.333397           0.410984      0.0   0.0  42.869473
# 3        0.041986       0.304128           0.240157      0.0   0.0  33.306160
# 4        0.007655       0.333397           0.024518      0.0   0.0  30.601074
# ...           ...            ...                ...      ...   ...        ...
# 2251     0.133148       0.467781           0.412495      0.0   0.0  42.106705
# 2252     0.051496       0.396554           0.281715      0.0   0.0  39.952632
# 2253     0.008119       0.467781           0.222557      0.0   0.0  41.291972
# 2254     0.047089       0.466767           0.665008      0.0   0.0  45.653680
# 2255     0.032707       0.386937           0.403197      0.0   0.0  36.850769
#
#              lon
# 0     -86.248392
# 1     -84.401346
# 2     -85.644749
# 3    -111.841300
# 4     -87.776333
# ...          ...
# 2251  -87.984554
# 2252  -75.165242
# 2253  -80.543845
# 2254 -122.546300
# 2255  -76.285873
#
# [2256 rows x 34 columns]
# 4.116788321167883
# C:\Users\rogmo\anaconda3\lib\site-packages\category_encoders\target_encoder.py:92: FutureWarning: Default parameter min_samples_leaf will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter min_samples_leaf will change in version 2.6."
# C:\Users\rogmo\anaconda3\lib\site-packages\category_encoders\target_encoder.py:97: FutureWarning: Default parameter smoothing will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter smoothing will change in version 2.6."
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_dev_clu['group_encoded'] = te_group.fit_transform(X_dev_clu['group'],y_dev_clu)
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_dev_clu.drop(columns = 'group', inplace = True)
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_clu['group_encoded'] = te_group.transform(X_test_clu['group'])
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_clu.drop(columns = 'group', inplace = True)
# C:\Users\rogmo\anaconda3\lib\site-packages\category_encoders\target_encoder.py:92: FutureWarning: Default parameter min_samples_leaf will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter min_samples_leaf will change in version 2.6."
# C:\Users\rogmo\anaconda3\lib\site-packages\category_encoders\target_encoder.py:97: FutureWarning: Default parameter smoothing will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter smoothing will change in version 2.6."
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_dev_clu['CBSA_NAME_encoded'] = te_CBSA_NAME.fit_transform(X_dev_clu['CBSA_NAME'],y_dev_clu)
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_dev_clu.drop(columns = 'CBSA_NAME', inplace = True)
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_clu['CBSA_NAME_encoded'] = te_CBSA_NAME.transform(X_test_clu['CBSA_NAME'])
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_clu.drop(columns = 'CBSA_NAME', inplace = True)
# [5, 10]
#       priv_count  mcare_los  mcare_pay_median  Hospitals  PctTeaching  \
# 0       0.281385   0.184378          0.317820   0.886700     0.132597
# 1       0.012987   0.000000          0.065249   0.133005     0.535714
# 2       0.038961   0.304214          0.312168   0.113300     0.375000
# 3       0.059163   0.690017          0.397455   0.182266     0.315789
# 4       0.088023   0.000000          0.559778   0.123153     0.173077
# ...          ...        ...               ...        ...          ...
# 1322    0.021645   0.000000          0.539755   0.024631     0.750000
# 1323    0.111111   0.000000          0.480212   0.108374     0.326087
# 1324    0.017316   0.356286          0.471536   0.182266     0.552632
# 1325    0.018759   0.536962          0.311413   0.389163     0.243750
# 1326    0.240981   0.000000          0.072707   0.389163     0.243750
#
#       PctLargeHospital  PctPrivate  total_population  median_age  sex_ratio  \
# 0             0.182320    0.823204          0.359532    0.139665      0.576
# 1             0.428571    0.571429          0.060223    0.212291      0.000
# 2             0.500000    0.583333          0.048895    0.368715      0.144
# 3             0.315789    0.710526          0.094744    0.245810      0.376
# 4             0.230769    0.576923          0.129799    0.296089      0.240
# ...                ...         ...               ...         ...        ...
# 1322          1.000000    0.500000          0.010917    0.111732      0.504
# 1323          0.260870    0.826087          0.129334    0.318436      0.416
# 1324          0.078947    0.421053          0.120094    0.351955      0.624
# 1325          0.150000    0.725000          0.305391    0.245810      0.160
# 1326          0.150000    0.725000          0.305391    0.245810      0.160
#
#       ...  frac_priv_insurance  frac_mcare_insurance  frac_no_insurance  \
# 0     ...             0.090909              0.250000             1.0000
# 1     ...             0.272727              0.571429             0.5000
# 2     ...             0.500000              0.500000             0.3125
# 3     ...             0.727273              0.285714             0.3750
# 4     ...             0.500000              0.357143             0.4375
# ...   ...                  ...                   ...                ...
# 1322  ...             0.586364              0.650000             0.1250
# 1323  ...             0.363636              0.392857             0.5625
# 1324  ...             0.636364              0.500000             0.1875
# 1325  ...             0.545455              0.250000             0.5625
# 1326  ...             0.545455              0.250000             0.5625
#
#       mcare_count  group_encoded  CBSA_NAME_encoded  cluster  site        lat  \
# 0        0.203339       0.520605           0.344939      2.0   1.0  29.598443
# 1        0.021174       0.000000           0.127613      2.0   0.0  35.038720
# 2        0.115169       0.593655           0.020322      2.0   1.0  33.405387
# 3        0.072373       0.590216           0.344120      2.0   1.0  36.214401
# 4        0.041340       0.766687           0.522388      2.0   0.0  35.122320
# ...           ...            ...                ...      ...   ...        ...
# 1322     0.055120       0.756568           0.268361      2.0   0.0  42.280830
# 1323     0.050639       0.756568           0.664447      2.0   0.0  28.582820
# 1324     0.127381       0.593655           0.510457      2.0   1.0  47.607680
# 1325     0.031257       0.000000           0.327401      2.0   1.0  34.075380
# 1326     0.043917       0.000000           0.327401      2.0   0.0  34.075380
#
#              lon
# 0     -95.622552
# 1     -89.850500
# 2     -86.811378
# 3     -86.580447
# 4     -80.721440
# ...          ...
# 1322  -83.743040
# 1323  -81.339940
# 1324 -122.195948
# 1325  -84.294090
# 1326  -84.294090
#
# [1327 rows x 34 columns]
# 3.949404761904762
# C:\Users\rogmo\anaconda3\lib\site-packages\category_encoders\target_encoder.py:92: FutureWarning: Default parameter min_samples_leaf will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter min_samples_leaf will change in version 2.6."
# C:\Users\rogmo\anaconda3\lib\site-packages\category_encoders\target_encoder.py:97: FutureWarning: Default parameter smoothing will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter smoothing will change in version 2.6."
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_dev_clu['group_encoded'] = te_group.fit_transform(X_dev_clu['group'],y_dev_clu)
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_dev_clu.drop(columns = 'group', inplace = True)
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_clu['group_encoded'] = te_group.transform(X_test_clu['group'])
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_clu.drop(columns = 'group', inplace = True)
# C:\Users\rogmo\anaconda3\lib\site-packages\category_encoders\target_encoder.py:92: FutureWarning: Default parameter min_samples_leaf will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter min_samples_leaf will change in version 2.6."
# C:\Users\rogmo\anaconda3\lib\site-packages\category_encoders\target_encoder.py:97: FutureWarning: Default parameter smoothing will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter smoothing will change in version 2.6."
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_dev_clu['CBSA_NAME_encoded'] = te_CBSA_NAME.fit_transform(X_dev_clu['CBSA_NAME'],y_dev_clu)
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_dev_clu.drop(columns = 'CBSA_NAME', inplace = True)
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_clu['CBSA_NAME_encoded'] = te_CBSA_NAME.transform(X_test_clu['CBSA_NAME'])
# C:\Users\rogmo\AppData\Local\Temp\ipykernel_24708\3174191158.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_clu.drop(columns = 'CBSA_NAME', inplace = True)
# [5, 10, 8]
#      priv_count  mcare_los  mcare_pay_median  Hospitals  PctTeaching  \
# 0      0.003279   0.088302          0.254348   0.025253     0.954545
# 1      0.003279   0.651961          0.180683   0.454545     0.640625
# 2      0.072131   0.109961          0.474117   0.010101     0.562500
# 3      0.242623   0.182604          0.493813   0.101010     0.173077
# 4      0.308197   0.197860          0.421624   0.217172     0.428571
# ..          ...        ...               ...        ...          ...
# 153    0.003279   0.207409          0.530751   0.202020     0.456522
# 154    0.052459   0.222567          0.541469   0.252525     0.187500
# 155    0.013115   0.701479          0.176382   0.161616     0.552632
# 156    0.311475   0.159521          0.499015   0.343434     0.344595
# 157    0.331148   0.207016          0.578934   0.454545     0.640625
#
#      PctLargeHospital  PctPrivate  total_population  median_age  sex_ratio  \
# 0            0.951395    0.509091          0.014981    0.773333   0.311927
# 1            0.515470    0.157500          0.096745    0.441667   0.496560
# 2            0.398515    0.910000          0.300571    0.533333   0.275229
# 3            0.218583    0.409231          0.118348    0.373333   0.275229
# 4            0.236209    0.845714          0.145131    0.933333   0.376147
# ..                ...         ...               ...         ...        ...
# 153          0.174774    0.681739          0.307289    0.346667   0.440367
# 154          0.064356    0.790000          0.185549    0.238333   0.784404
# 155          0.029182    0.147368          0.154097    0.288333   0.786697
# 156          0.183570    0.620541          0.234323    0.306667   0.706422
# 157          0.515470    0.157500          0.096745    0.441667   0.496560
#
#      ...  frac_priv_insurance  frac_mcare_insurance  frac_no_insurance  \
# 0    ...               0.5000              0.894737           0.187500
# 1    ...               0.7500              0.657895           0.140625
# 2    ...               0.7500              0.684211           0.125000
# 3    ...               0.5500              0.421053           0.437500
# 4    ...               0.3000              0.736842           0.500000
# ..   ...                  ...                   ...                ...
# 153  ...               0.9500              0.263158           0.250000
# 154  ...               0.2625              0.750000           0.468750
# 155  ...               0.3375              0.750000           0.390625
# 156  ...               0.4000              0.631579           0.500000
# 157  ...               0.7500              0.657895           0.140625
#
#      mcare_count  group_encoded  CBSA_NAME_encoded  cluster  site        lat  \
# 0       0.050122       0.648159           0.539279      1.0   1.0  41.081445
# 1       0.324574       0.000000           0.197641      1.0   1.0  42.106700
# 2       0.080292       0.648159           0.592232      1.0   1.0  39.952632
# 3       0.313869       0.648159           0.439849      1.0   1.0  35.122317
# 4       0.297324       0.648159           0.618005      1.0   1.0  28.274347
# ..           ...            ...                ...      ...   ...        ...
# 153     0.158637       1.000000           0.562248      1.0   1.0  39.134974
# 154     0.221411       0.648159           0.747354      1.0   1.0  33.750247
# 155     0.097810       0.000000           0.558218      1.0   1.0  47.607680
# 156     0.541606       0.648159           0.537318      1.0   1.0  33.306160
# 157     0.868127       0.648159           0.197641      1.0   1.0  42.106705
#
#             lon
# 0    -81.519005
# 1    -87.984550
# 2    -75.165242
# 3    -80.721442
# 4    -82.388578
# ..          ...
# 153  -77.368316
# 154 -117.888522
# 155 -122.195900
# 156 -111.841250
# 157  -87.984554
#
# [158 rows x 34 columns]
# 3.0384615384615383
#       priv_count  mcare_los  mcare_pay_median  Hospitals  PctTeaching  \
# 0       0.018231        0.0          0.184984   0.019704     0.400000
# 1       0.008043        0.0          0.217169   0.004926     0.000000
# 2       0.030563        0.0          0.205680   0.064039     0.428571
# 3       0.145308        0.0          0.193842   0.359606     0.229730
# 4       0.007507        0.0          0.170952   0.009852     0.666667
# ...          ...        ...               ...        ...          ...
# 2251    0.147989        0.0          0.229240   0.467980     0.427083
# 2252    0.044504        0.0          0.235769   0.034483     0.375000
# 2253    0.004290        0.0          0.166205   0.073892     0.500000
# 2254    0.100804        0.0          0.393522   0.142857     0.366667
# 2255    0.001072        0.0          0.208118   0.093596     0.500000
#
#       PctLargeHospital  PctPrivate  total_population  median_age  sex_ratio  \
# 0             0.000000    0.400000          0.004727    0.518657   0.422460
# 1             0.000000    0.000000          0.003891    0.559701   0.828877
# 2             0.214286    0.357143          0.051215    0.395522   0.540107
# 3             0.202703    0.702703          0.247025    0.436567   0.524064
# 4             0.000000    1.000000          0.007917    0.671642   0.208556
# ...                ...         ...               ...         ...        ...
# 2251          0.468750    0.427083          0.478889    0.470149   0.401070
# 2252          0.375000    0.875000          0.312174    0.500000   0.272727
# 2253          0.187500    0.625000          0.023094    0.675373   0.385027
# 2254          0.400000    0.666667          0.123304    0.492537   0.529412
# 2255          0.300000    0.500000          0.087527    0.417910   0.422460
#
#       ...  frac_priv_insurance  frac_mcare_insurance  frac_no_insurance  \
# 0     ...             0.795652              0.606061           0.085714
# 1     ...             0.795652              0.660606           0.085714
# 2     ...             0.847826              0.484848           0.071429
# 3     ...             0.652174              0.545455           0.285714
# 4     ...             0.678261              0.715152           0.257143
# ...   ...                  ...                   ...                ...
# 2251  ...             0.739130              0.484848           0.178571
# 2252  ...             0.804348              0.575758           0.071429
# 2253  ...             0.521739              0.969697           0.107143
# 2254  ...             0.782609              0.545455           0.107143
# 2255  ...             0.826087              0.575758           0.107143
#
#       mcare_count  group_encoded  CBSA_NAME_encoded  cluster  site        lat  \
# 0        0.018789       0.333397           0.171516      0.0   0.0  43.234181
# 1        0.022965       0.396554           0.140901      0.0   0.0  42.245869
# 2        0.026212       0.333397           0.410984      0.0   0.0  42.869473
# 3        0.041986       0.304128           0.240157      0.0   0.0  33.306160
# 4        0.007655       0.333397           0.024518      0.0   0.0  30.601074
# ...           ...            ...                ...      ...   ...        ...
# 2251     0.133148       0.467781           0.412495      0.0   0.0  42.106705
# 2252     0.051496       0.396554           0.281715      0.0   0.0  39.952632
# 2253     0.008119       0.467781           0.222557      0.0   0.0  41.291972
# 2254     0.047089       0.466767           0.665008      0.0   0.0  45.653680
# 2255     0.032707       0.386937           0.403197      0.0   0.0  36.850769
#
#              lon
# 0     -86.248392
# 1     -84.401346
# 2     -85.644749
# 3    -111.841300
# 4     -87.776333
# ...          ...
# 2251  -87.984554
# 2252  -75.165242
# 2253  -80.543845
# 2254 -122.546300
# 2255  -76.285873
#
# [2256 rows x 34 columns]

# %% [markdown]
# ## Run XGBoost model

# %%
train_mapes = []
train_sizes = []
test_mapes = []
test_sizes = []

# Train test split
for idx in range(0,len(X_dev_list)):

    X_train, X_val, y_train, y_val = train_test_split(X_dev_list[idx],
                                                        y_dev_list[idx],
                                                        train_size = TRAIN_TEST_PROPORTION,
                                                        random_state = RDM_SEED)
    
    # Parameterization
    mono = {'site': 1}

    param_grid = {
        'booster':['gbtree','dart'],
        'colsample_bylevel':[1],
        'colsample_bytree':[1],
        'enable_categorical':[False],
        'gamma':[0],
        'gpu_id':[-1],
        'interaction_constraints':[''],
        'max_delta_step':[0],
        'min_child_weight':[1],
        'missing':[np.nan],
#         'n_estimators':[100,175,250],
        'n_jobs':[8],
        'predictor':['auto'],
        'reg_alpha':[0],
        'scale_pos_weight':[1],
        'tree_method':['exact'],
        'validate_parameters':[1],
        'learning_rate':[1],
#         'max_depth':[10,17,25],
        'num_parallel_tree':[250],
        'objective':['reg:squarederror'],
        'subsample':[0.8],
        'random_state':[RDM_SEED],
        'reg_lambda':[0,0.25,0.5]
    }
    
    # Create, run, and tune (if applicable) model
    xgb_param_tuning_model = xgb.XGBRFRegressor(monotone_constraints = mono,
                                                n_estimators = 250,
                                                max_depth=25#,
#                                                 reg_lambda=0
                                               )
    
    xgb_mono_model = GridSearchCV(xgb_param_tuning_model, param_grid, scoring='neg_mean_absolute_percentage_error')
    xgb_mono_model.fit(X_train, y_train)
    
    # Output optimal params (if applicable)
    print(f"Best parameters (if grid search was applied): {xgb_mono_model.best_params_}")
    
    # Predict on train and test data
    y_train_pred_xgb = xgb_mono_model.predict(X_train)
    y_test_pred_xgb = xgb_mono_model.predict(X_test_list[idx])

    # Store results
    train_sizes.append(len(X_train))
    test_sizes.append(len(X_test_list[idx]))
    train_mapes.append(mean_absolute_percentage_error(y_true=y_train, y_pred=y_train_pred_xgb))
    test_mapes.append(mean_absolute_percentage_error(y_true=y_test_list[idx], y_pred=y_test_pred_xgb))
    

train_mapes = np.array(train_mapes)
train_sizes = np.array(train_sizes)
test_mapes = np.array(test_mapes)
test_sizes = np.array(test_sizes)

# Output results?
print(f"Monotonic XGBoost with Threshold >{COUNT_THRESH} claims for training set:")
print(f"Train MAPEs: {train_mapes}")
print(f"Train sizes: {train_sizes}")
print(f"Test MAPEs: {test_mapes}")
print(f"Test sizes: {test_sizes}")
print(f"Total train MAPE: {((train_mapes * train_sizes) / (train_sizes.sum())).sum()}")
print(f"Total test MAPE: {((test_mapes * test_sizes) / (test_sizes.sum())).sum()}")
# Out:
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# Best parameters (if grid search was applied): {'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0, 'gpu_id': -1, 'interaction_constraints': '', 'learning_rate': 1, 'max_delta_step': 0, 'min_child_weight': 1, 'missing': nan, 'n_jobs': 8, 'num_parallel_tree': 250, 'objective': 'reg:squarederror', 'predictor': 'auto', 'random_state': 123, 'reg_alpha': 0, 'reg_lambda': 0.25, 'scale_pos_weight': 1, 'subsample': 0.8, 'tree_method': 'exact', 'validate_parameters': 1}
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# Best parameters (if grid search was applied): {'booster': 'dart', 'colsample_bylevel': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0, 'gpu_id': -1, 'interaction_constraints': '', 'learning_rate': 1, 'max_delta_step': 0, 'min_child_weight': 1, 'missing': nan, 'n_jobs': 8, 'num_parallel_tree': 250, 'objective': 'reg:squarederror', 'predictor': 'auto', 'random_state': 123, 'reg_alpha': 0, 'reg_lambda': 0, 'scale_pos_weight': 1, 'subsample': 0.8, 'tree_method': 'exact', 'validate_parameters': 1}
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\rogmo\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# Best parameters (if grid search was applied): {'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0, 'gpu_id': -1, 'interaction_constraints': '', 'learning_rate': 1, 'max_delta_step': 0, 'min_child_weight': 1, 'missing': nan, 'n_jobs': 8, 'num_parallel_tree': 250, 'objective': 'reg:squarederror', 'predictor': 'auto', 'random_state': 123, 'reg_alpha': 0, 'reg_lambda': 0, 'scale_pos_weight': 1, 'subsample': 0.8, 'tree_method': 'exact', 'validate_parameters': 1}
# Monotonic XGBoost with Threshold >34 claims for training set:
# Train MAPEs: [0.11249314 0.03323256 0.02969441]
# Train sizes: [1804 1061  126]
# Test MAPEs: [0.15361186 0.16055404 0.21116337]
# Test sizes: [548 336  52]
# Total train MAPE: 0.08088895754701034
# Total test MAPE: 0.15930123002922153
