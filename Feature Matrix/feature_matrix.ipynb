# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

pd.options.mode.chained_assignment = None
sns.set_style("darkgrid");
plt.style.use('ggplot')

# %config InlineBackend.figure_format = 'retina'

# %%
df_raw = pd.read_csv('combined_features.csv')
df_raw.head()
# Out:
#      msa  year       site                  group  priv_count  priv_pay_mean  \
# 0  10420  2018  Inpatient  breast reconstruction           8    19937.08375
# 1  10580  2018  Inpatient  breast reconstruction           4    14837.26000
# 2  10900  2018  Inpatient  breast reconstruction           1    11658.00000
# 3  11020  2018  Inpatient  breast reconstruction           1    24543.00000
# 4  11244  2018  Inpatient  breast reconstruction           9    25467.99000
#
#    priv_pay_median  priv_pay_iqr  mcare_los  mcare_pay_mean  ...  \
# 0        16147.330       5692.86   2.000000      8313.84750  ...
# 1        10420.675       4474.06   2.888889      9230.50000  ...
# 2        11658.000          0.00   4.222222     10730.78778  ...
# 3        24543.000          0.00        NaN             NaN  ...
# 4        27320.610      17249.00   2.916667     13611.27167  ...
#
#    frac_veteran  frac_disability non_citizen employment_rate  \
# 0          0.06             0.14        0.40            0.63
# 1          0.06             0.13        0.38            0.63
# 2          0.06             0.13        0.42            0.64
# 3           NaN              NaN         NaN             NaN
# 4           NaN              NaN         NaN             NaN
#
#    frac_priv_insurance  frac_mcare_insurance  frac_no_insurance  poverty_rate  \
# 0                 0.68                  0.40               0.06          0.09
# 1                 0.74                  0.38               0.03          0.07
# 2                 0.72                  0.37               0.06          0.08
# 3                  NaN                   NaN                NaN           NaN
# 4                  NaN                   NaN                NaN           NaN
#
#         emp          ap
# 0  296941.0  14549253.0
# 1  364490.0  19095678.0
# 2  338802.0  17175532.0
# 3   53539.0   2215160.0
# 4       NaN         NaN
#
# [5 rows x 44 columns]

# %%
df_clusters = pd.read_csv('clusters_only_using_NormCost.csv')
df_clusters.head()
# Out:
#                    group  cluster
# 0              ankle_fix        2
# 1        ant_cerv_fusion        2
# 2         ant_tls_fusion        1
# 3              bariatric        0
# 4  breast reconstruction        0

# %%
df_with_clusters = df_raw.merge(df_clusters, how='left', on='group')
df_with_clusters.head()
# Out:
#      msa  year       site                  group  priv_count  priv_pay_mean  \
# 0  10420  2018  Inpatient  breast reconstruction           8    19937.08375
# 1  10580  2018  Inpatient  breast reconstruction           4    14837.26000
# 2  10900  2018  Inpatient  breast reconstruction           1    11658.00000
# 3  11020  2018  Inpatient  breast reconstruction           1    24543.00000
# 4  11244  2018  Inpatient  breast reconstruction           9    25467.99000
#
#    priv_pay_median  priv_pay_iqr  mcare_los  mcare_pay_mean  ...  \
# 0        16147.330       5692.86   2.000000      8313.84750  ...
# 1        10420.675       4474.06   2.888889      9230.50000  ...
# 2        11658.000          0.00   4.222222     10730.78778  ...
# 3        24543.000          0.00        NaN             NaN  ...
# 4        27320.610      17249.00   2.916667     13611.27167  ...
#
#    frac_disability  non_citizen employment_rate frac_priv_insurance  \
# 0             0.14         0.40            0.63                0.68
# 1             0.13         0.38            0.63                0.74
# 2             0.13         0.42            0.64                0.72
# 3              NaN          NaN             NaN                 NaN
# 4              NaN          NaN             NaN                 NaN
#
#    frac_mcare_insurance  frac_no_insurance  poverty_rate       emp  \
# 0                  0.40               0.06          0.09  296941.0
# 1                  0.38               0.03          0.07  364490.0
# 2                  0.37               0.06          0.08  338802.0
# 3                   NaN                NaN           NaN   53539.0
# 4                   NaN                NaN           NaN       NaN
#
#            ap  cluster
# 0  14549253.0        0
# 1  19095678.0        0
# 2  17175532.0        0
# 3   2215160.0        0
# 4         NaN        0
#
# [5 rows x 45 columns]

# %%
df_preprocessed = df_with_clusters.drop(['FIPS.State.Code', 'poverty_rate', 'emp', 'ap', 'State', 'group'],
                          axis=1)
df_preprocessed.head()
# Out:
#      msa  year       site  priv_count  priv_pay_mean  priv_pay_median  \
# 0  10420  2018  Inpatient           8    19937.08375        16147.330
# 1  10580  2018  Inpatient           4    14837.26000        10420.675
# 2  10900  2018  Inpatient           1    11658.00000        11658.000
# 3  11020  2018  Inpatient           1    24543.00000        24543.000
# 4  11244  2018  Inpatient           9    25467.99000        27320.610
#
#    priv_pay_iqr  mcare_los  mcare_pay_mean  mcare_pay_median  ...  \
# 0       5692.86   2.000000      8313.84750           8298.49  ...
# 1       4474.06   2.888889      9230.50000           8003.40  ...
# 2          0.00   4.222222     10730.78778           8083.55  ...
# 3          0.00        NaN             NaN               NaN  ...
# 4      17249.00   2.916667     13611.27167          12005.46  ...
#
#    frac_educated annual_births  frac_veteran  frac_disability  non_citizen  \
# 0           0.92      160665.0          0.06             0.14         0.40
# 1           0.93      208912.0          0.06             0.13         0.38
# 2           0.91      191596.0          0.06             0.13         0.42
# 3            NaN           NaN           NaN              NaN          NaN
# 4            NaN           NaN           NaN              NaN          NaN
#
#    employment_rate  frac_priv_insurance  frac_mcare_insurance  \
# 0             0.63                 0.68                  0.40
# 1             0.63                 0.74                  0.38
# 2             0.64                 0.72                  0.37
# 3              NaN                  NaN                   NaN
# 4              NaN                  NaN                   NaN
#
#    frac_no_insurance  cluster
# 0               0.06        0
# 1               0.03        0
# 2               0.06        0
# 3                NaN        0
# 4                NaN        0
#
# [5 rows x 39 columns]

# %%
# OHE
def map_site(val):
    if val == 'Inpatient':
        return 1
    return 0
    
df_preprocessed['site'] = df_preprocessed['site'].map(lambda x: map_site(x))

# %%
# Target Encoding

from category_encoders import TargetEncoder

te = TargetEncoder(handle_unknown='ignore')
df_preprocessed['CBSA_NAME'] = te.fit_transform(df_preprocessed['CBSA_NAME'], df_preprocessed['priv_pay_median'])

# %%
from KNN_function import knn_func
df_imputed = knn_func(df_preprocessed)

# %%
df_imputed.dtypes
# Out:
# msa                               float64
# year                              float64
# site                              float64
# priv_count                        float64
# priv_pay_mean                     float64
# priv_pay_median                   float64
# priv_pay_iqr                      float64
# mcare_los                         float64
# mcare_pay_mean                    float64
# mcare_pay_median                  float64
# mcare_pay_sd                      float64
# CBSA_NAME                         float64
# lon                               float64
# lat                               float64
# Hospitals                         float64
# PctTeaching                       float64
# PctLargeHospital                  float64
# PctPrivate                        float64
# total_population                  float64
# median_age                        float64
# sex_ratio                         float64
# State_Poverty_Percent_All_Ages    float64
# State_Median_Household_Income     float64
# income_pc                         float64
# num_races                         float64
# household_size                    float64
# frac_married                      float64
# frac_school                       float64
# frac_college                      float64
# frac_educated                     float64
# annual_births                     float64
# frac_veteran                      float64
# frac_disability                   float64
# non_citizen                       float64
# employment_rate                   float64
# frac_priv_insurance               float64
# frac_mcare_insurance              float64
# frac_no_insurance                 float64
# cluster                           float64
# dtype: object

# %%
np.sum(df_imputed.isna())
# Out:
# msa                               0
# year                              0
# site                              0
# priv_count                        0
# priv_pay_mean                     0
# priv_pay_median                   0
# priv_pay_iqr                      0
# mcare_los                         0
# mcare_pay_mean                    0
# mcare_pay_median                  0
# mcare_pay_sd                      0
# CBSA_NAME                         0
# lon                               0
# lat                               0
# Hospitals                         0
# PctTeaching                       0
# PctLargeHospital                  0
# PctPrivate                        0
# total_population                  0
# median_age                        0
# sex_ratio                         0
# State_Poverty_Percent_All_Ages    0
# State_Median_Household_Income     0
# income_pc                         0
# num_races                         0
# household_size                    0
# frac_married                      0
# frac_school                       0
# frac_college                      0
# frac_educated                     0
# annual_births                     0
# frac_veteran                      0
# frac_disability                   0
# non_citizen                       0
# employment_rate                   0
# frac_priv_insurance               0
# frac_mcare_insurance              0
# frac_no_insurance                 0
# cluster                           0
# dtype: int64

# %%
df_imputed.to_csv('feature_matrix_draft1.csv')
